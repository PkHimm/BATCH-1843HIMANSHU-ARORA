# %% [markdown]
# Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Advertising.csv')
print(df)
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# using this below input, we find first five rows of dataset

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# This function is used to access the last 5 rows of a dataframe.

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# The below function is used to access the last 5 rows of a dataframe.

# %%
df.isnull().any()
# Out:
# Unnamed: 0    False
# TV            False
# radio         False
# newspaper     False
# sales         False
# dtype: bool

# %% [markdown]
# This function gives information about any Null Value is present in our Data frame. if all the values are False as shown above then we say there is not any null value is present in our data frame.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# This function gives information about any data is missing or Not.

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# With the help of Double sum Function we find our missing value is zero.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# This function is used to print the information given in our Dataframe. This function gives information about the Data type(float, object, int), columns.

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# This function gives information about the Description of our Data Frame.

# %%
df.hist(bins=5,figsize=(15,15))
# display histogram
plt.show()

# %% [markdown]
# Here above Figure Shows Histogram Plot, The Bins=5 shows here, that our graph is divided into 5 bars, if we use Bins= 15, than our graph is divided into 15 bars, figsize is used here to show the size of each Graph.For Example:- Here (15,15) shows the Breadth and Height of Each Individual Graph.

# %%
plt.figure(figsize=[10,7])
# plot bar graph
plt.bar(df['sales'],df['newspaper'])
plt.xlabel("sales")
plt.ylabel("newspaper")
plt.show()

# %% [markdown]
# Here above Figure Shows bar graph Plot, at 12 max number of sale is found in newspaper.

# %%
plt.figure(figsize=[10,7])
# plot bar graph
plt.bar(df['sales'],df['radio'])
plt.xlabel("sales")
plt.ylabel("radio")
plt.show()

# %% [markdown]
# Here above Figure Shows bar graph Plot, at 15 max number of sale is found in Radio.

# %%
plt.figure(figsize=[10,7])
# plot bar graph
plt.bar(df['sales'],df['TV'])
plt.xlabel("sales")
plt.ylabel("TV")
plt.show()

# %% [markdown]
# Here above Figure Shows bar graph Plot, at 22 max number of sale is found in TV with 260 Numbers.

# %%
#plotting Heatmap
plt.figure(figsize=[15,10],facecolor='blue')
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here fig size say 15 in horizontal axis and 10 in Vertical axis, facecolor= blue says that color around them. As per the histogram Plot, Newspaper and radio has almost same number, sales is different from all factor.

# %%
plt.figure(figsize=(40,40))
sns.countplot('radio', data=df)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Here above fig shows a countplot, Between Radio and count and we find in this,for value of 74 & 95 the no of count is high, as compare to others.

# %%
plt.figure(figsize=(40,40))
sns.countplot('newspaper', data=df)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Here above fig shows a countplot, Between newspaper and count and we find in this,for value of 39 the no of count is high, as compare to others.

# %%
plt.figure(figsize=(40,40))
sns.countplot('sales', data=df)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# above input, we find the correlation between each columns.

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %% [markdown]
# From above input, we find any duplicated value in our dataset. if all values come false then our data set is ok.

# %%
sns.scatterplot(x='sales',y='newspaper',data=df,s=200);
plt.grid()

# %% [markdown]
# First of All, Scatter plot Diagram is a Data Visualization Technique and it is plot when Both X And Y axis are in a Numerical Form, if any of the case one is categorical and other one is Numerical than Graph is not Plotted. Here, Grid shows the Lines In above Diagram, X sales & y Shows newspaper. This is big data set if we try to explain then, the first value of sales= 22.1 and First value of newspaper is 69.2, then where both point Coincide then a Dot is plot,Similarly all 200 data our Scatter plot Shown above.

# %%
sns.scatterplot(x='sales',y='radio',data=df,s=200);
plt.grid()

# %% [markdown]
# First of All, Scatter plot Diagram is a Data Visualization Technique and it is plot when Both X And Y axis are in a Numerical Form, if any of the case one is categorical and other one is Numerical than Graph is not Plotted. Here, Grid shows the Lines In above Diagram, X sales & y Shows radio. This is big data set if we try to explain then, the first value of sales= 22.1 and First value of radio is 37.8, then where both point Coincide then a Dot is plot,Similarly all 200 data our Scatter plot Shown above.

# %%
sns.scatterplot(x='sales',y='TV',data=df,s=200);
plt.grid()

# %% [markdown]
# First of All, Scatter plot Diagram is a Data Visualization Technique and it is plot when Both X And Y axis are in a Numerical Form, if any of the case one is categorical and other one is Numerical than Graph is not Plotted. Here, Grid shows the Lines In above Diagram, X sales & y Shows TV. This is big data set if we try to explain then, the first value of sales= 22.1 and First value of TV is 230.1, then where both point Coincide then a Dot is plot,Similarly all 200 data our Scatter plot Shown above.

# %%
X=df.drop('sales',axis=1)
Y=df['sales']

# %% [markdown]
# seperate the output data with complete data set.

# %%
X.shape , Y.shape
# Out:
# ((200, 4), (200,))

# %% [markdown]
# The above input shows, 200 Rows and 4 columns here

# %%
#splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, 
                                                    random_state=1) 
X_train.shape , X_test.shape ,Y_train.shape , Y_test.shape
# Out:
# ((140, 4), (60, 4), (140,), (60,))

# %% [markdown]
# From above input we find that, Divide the data into Train and Testing.

# %% [markdown]
# Insert Linear Regression and mean squared error Libraries.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score , mean_squared_error

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predict the model in Linear Regression with X_test and Y_test.

# %%
#Test Model
pred = lr.predict(X_test)
pred
# Out:
# array([21.66726472, 16.44886585,  7.70162782, 17.91693951, 18.6598302 ,
#        23.77686855, 16.28148316, 13.45215658,  9.16134283, 17.31440772,
#        14.42914135,  9.85120603, 17.27607345, 16.62782623, 15.08911406,
#        15.49601481, 12.42628103, 17.33599227, 11.03927674, 18.06273193,
#         9.36111799, 12.7997845 ,  8.74017775, 10.47426246, 11.39043595,
#        15.01903559,  9.7479584 , 19.45620185, 18.18124577, 17.21163034,
#        21.57046641, 14.69384162, 16.25255007, 12.36123532, 19.96129204,
#        15.36852746, 13.99610286, 10.08100899, 20.9223882 ,  7.42982649,
#         3.66996929,  7.27759842,  5.98440814, 18.4246142 ,  8.3232281 ,
#        14.11983162, 14.93410073, 20.36600912, 20.551861  , 19.54783442,
#        24.10207685, 14.84753143,  6.71277509, 19.78115551, 18.95031714,
#        12.50189261, 14.19083579,  6.10782886, 15.35859061,  9.56315359])

# %%
Y_test
# Out:
# 58     23.8
# 40     16.6
# 34      9.5
# 102    14.8
# 184    17.6
# 198    25.5
# 95     16.9
# 4      12.9
# 29     10.5
# 168    17.1
# 171    14.5
# 18     11.3
# 11     17.4
# 89     16.7
# 110    13.4
# 118    15.9
# 159    12.9
# 35     12.8
# 136     9.5
# 59     18.4
# 51     10.7
# 16     12.5
# 44      8.5
# 94     11.5
# 31     11.9
# 162    14.9
# 38     10.1
# 28     18.9
# 193    19.6
# 27     15.9
# 47     23.2
# 165    11.9
# 194    17.3
# 177    11.7
# 176    20.2
# 97     15.5
# 174    11.5
# 73     11.0
# 69     22.3
# 172     7.6
# 108     5.3
# 107     8.7
# 189     6.7
# 14     19.0
# 56      5.5
# 19     14.6
# 114    14.6
# 39     21.5
# 185    22.6
# 124    19.7
# 98     25.4
# 123    15.2
# 119     6.6
# 53     21.2
# 33     17.4
# 179    12.6
# 181    12.2
# 106     7.2
# 199    13.4
# 138     9.6
# Name: sales, dtype: float64

# %% [markdown]
# Find the Score of your Dataset.

# %%
#Evaluate
lr.score(X_test , Y_test)
# Out:
# 0.9225191550357025

# %%
rmse =np.sqrt(mean_squared_error(Y_test,pred))
r2 = r2_score(Y_test,pred)

# %%
rmse , r2
# Out:
# (1.3883326405075882, 0.9225191550357025)

# %% [markdown]
# Thanks
